# %% [markdown]
# **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'

# %%
print(len(long_phrase)>len(short_phrase))
# Out:
# True

# %% [markdown]
# **Задание 2**. Дано значение объема файла в байтах (*в мегабайте 2^20 байт*). Напишите перевод этого значения в мегабайты в формате: "*Объем файла равен 213.68Mb*".

# %%
bt = int(input("Введите кол-во байт: ")) #вводим данные
mb1 = int(2**20) #получаем размер байтов в 1Мб
mb = str(round(bt/mb1, 3)) #вычисляем и делаем строковой переменной
print("Объем файла равен " + mb + "Mb") #выводим на экран
# Out:
# Введите кол-во байт: 104224
# Объем файла равен 0.099Mb

# %% [markdown]
# **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
signs = {
1:{"sign":"Козерог", "date_from":101, "date_to":119},
2:{"sign":"Водолей", "date_from":122, "date_to":218},
3:{"sign":"Рыбы", "date_from":219, "date_to":320},
4:{"sign":"Овен", "date_from":321, "date_to":420},
5:{"sign":"Телец", "date_from":421, "date_to":520},
6:{"sign":"Близнецы", "date_from":521, "date_to":620},
7:{"sign":"Рак", "date_from":621, "date_to":722},
8:{"sign":"Лев", "date_from":723, "date_to":822},
9:{"sign":"Дева", "date_from":823, "date_to":923},
10:{"sign":"Весы", "date_from":924, "date_to":1023},
11:{"sign":"Скорпион", "date_from":1024, "date_to":1121},
12:{"sign":"Стрелец", "date_from":1122, "date_to":1221},
13:{"sign":"Козерог", "date_from":1222, "date_to":1231}
}
months = {"январь":1, "февраль":2,"март":3,"апрель":4,"май":5,"июнь":6,"июль":7,"август":8,"сентябрь":9,
          "октябрь":10,"ноябрь":11,"декабрь":12}
month = input("Введите месяц: ")
day = int(input("Введите число: "))
mn=months.get(month, "Такого месяца не существует")
if(mn!='' and 1<day<=31):
    for elm in signs:
        if(signs[elm]["date_from"] < int(mn)*100+day < signs[elm]["date_to"]):
            print ("Вывод: "+signs[elm]["sign"])
# Out:
# Введите месяц: май
# Введите число: 23
# Вывод: Близнецы

# %% [markdown]
# **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
print("Укажите вашу")
salary = int(input("Заработанную плату в месяц: ")) #Ввод данных
mortgage = int(input("Сколько процентов от ЗП уходит на ипотеку: "))
life = int(input("Сколько процентов от ЗП уходит 'на жизнь': "))
bonus = int(input("Сколько раз приходит премия в год: "))
year_mortgage = round(mortgage*salary/100)*12 #Потрачено на ипотеку в год
year_life = round(life*salary/100)*12 #Потрачено на жизнь в год
spent = (year_mortgage+year_life)-round(salary*bonus/2) #Всего потрачено в год
save=salary*12-spent #Всего накоплено

print("Вывод:\nНа ипотеку было потрачено: "+str(year_mortgage)+" рублей\nБыло накоплено: "+str(save)+" рублей")
# Out:
# Укажите вашу
# Заработанную плату в месяц: 100000
# Сколько процентов от ЗП уходит на ипотеку: 30
# Сколько процентов от ЗП уходит 'на жизнь': 50
# Сколько раз приходит премия в год: 2
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей
